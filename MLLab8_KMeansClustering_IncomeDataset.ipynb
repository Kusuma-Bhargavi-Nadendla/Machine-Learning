# %% [markdown]
# <a href="https://colab.research.google.com/github/Kusuma-Bhargavi-Nadendla/Machine-Learning/blob/main/MLLab8_KMeansClustering_IncomeDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
customers_df=pd.read_csv("Income Data.csv")

customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   income  300 non-null    float64
#  1   age     300 non-null    float64
# dtypes: float64(2)
# memory usage: 4.8 KB

# %%
customers_df.head(5)
# Out:
#     income    age
# 0  41100.0  48.75
# 1  54100.0  28.10
# 2  47800.0  46.75
# 3  19100.0  40.25
# 4  18200.0  35.80

# %%
sn.lmplot(x="age", y="income", data=customers_df, fit_reg=False, height=4)
