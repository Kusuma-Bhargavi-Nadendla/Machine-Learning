# %% [markdown]
# <a href="https://colab.research.google.com/github/Kusuma-Bhargavi-Nadendla/Machine-Learning/blob/main/MLLab9_AssociationRulesForRecommendationSystems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
all_txns = []

#open the file

with open('groceries.csv') as f:

    #read each Line

    content =f.readlines()

    #Remove white space from the beginning and end of the Line


    txns = [x.strip() for x in content]

    # Iterate through each line and create a list of transactions

    for each_txn in txns:

        #Each transaction will contain a list of item in the transaction all_txns.append(each_txn.split(','))
        all_txns.append(each_txn.split(','))

# %%
all_txns[0:5]
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese ', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product']]

# %%
# Import all required libraries

import pandas as pd

import numpy as np

from mlxtend.preprocessing import TransactionEncoder

from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Initialize OnehotTransactions

one_hot_encoding = TransactionEncoder()

# Transform the data into one-hot-encoding format

one_hot_txns = one_hot_encoding.fit (all_txns).transform (all_txns)

# Convert the matrix into the dataframe.

one_hot_txns_df = pd.DataFrame (one_hot_txns, columns=one_hot_encoding.columns_)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
one_hot_txns_df.iloc[5:10, 10:20]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    berries  beverages  bottled beer  bottled water  brandy  brown bread  \
# 5    False      False         False          False   False        False
# 6    False      False         False          False   False        False
# 7    False      False          True          False   False        False
# 8    False      False         False          False   False        False
# 9    False      False         False          False   False        False
#
#    butter  butter milk  cake bar  candles
# 5    True        False     False    False
# 6   False        False     False    False
# 7   False        False     False    False
# 8   False        False     False    False
# 9   False        False     False    False

# %%
one_hot_txns_df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (9835, 171)

# %%
frequent_itemsets = apriori(one_hot_txns_df,

min_support=0.02,

use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
frequent_itemsets.sample(10, random_state = 90)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       support                            itemsets
# 60   0.020437          (bottled beer, whole milk)
# 52   0.033859                             (sugar)
# 89   0.035892  (tropical fruit, other vegetables)
# 105  0.021047   (tropical fruit, root vegetables)
# 88   0.032740            (other vegetables, soda)
# 16   0.058058                            (coffee)
# 111  0.024504         (whole milk, shopping bags)
# 36   0.079817                        (newspapers)
# 119  0.056024                (yogurt, whole milk)
# 55   0.071683                (whipped/sour cream)

# %%
rules=association_rules(frequent_itemsets,#itemsets
                        metric="lift",#lift
                        min_threshold=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
rules.sample(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                  antecedents   consequents  antecedent support  \
# 36   (fruit/vegetable juice)  (whole milk)            0.072293
# 5            (bottled water)  (rolls/buns)            0.110524
# 102                 (yogurt)        (soda)            0.139502
# 64              (rolls/buns)      (pastry)            0.183935
# 97              (whole milk)     (sausage)            0.255516
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 36             0.255516  0.026640    0.368495  1.442160  0.008168    1.178904
# 5              0.183935  0.024199    0.218951  1.190373  0.003870    1.044832
# 102            0.174377  0.027351    0.196064  1.124368  0.003025    1.026976
# 64             0.088968  0.020946    0.113875  1.279956  0.004581    1.028108
# 97             0.093950  0.029893    0.116992  1.245252  0.005887    1.026094
#
#      zhangs_metric
# 36        0.330488
# 5         0.179800
# 102       0.128543
# 64        0.268022
# 97        0.264545

# %%
rules.sort_values('confidence',ascending=False)[0:10]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                              antecedents         consequents  \
# 120           (yogurt, other vegetables)        (whole milk)
# 16                              (butter)        (whole milk)
# 24                                (curd)        (whole milk)
# 114  (root vegetables, other vegetables)        (whole milk)
# 115        (root vegetables, whole milk)  (other vegetables)
# 28                       (domestic eggs)        (whole milk)
# 108                 (whipped/sour cream)        (whole milk)
# 90                     (root vegetables)        (whole milk)
# 50                     (root vegetables)  (other vegetables)
# 32                   (frozen vegetables)        (whole milk)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 120            0.043416            0.255516  0.022267    0.512881  2.007235
# 16             0.055414            0.255516  0.027555    0.497248  1.946053
# 24             0.053279            0.255516  0.026131    0.490458  1.919481
# 114            0.047382            0.255516  0.023183    0.489270  1.914833
# 115            0.048907            0.193493  0.023183    0.474012  2.449770
# 28             0.063447            0.255516  0.029995    0.472756  1.850203
# 108            0.071683            0.255516  0.032232    0.449645  1.759754
# 90             0.108998            0.255516  0.048907    0.448694  1.756031
# 50             0.108998            0.193493  0.047382    0.434701  2.246605
# 32             0.048094            0.255516  0.020437    0.424947  1.663094
#
#      leverage  conviction  zhangs_metric
# 120  0.011174    1.528340       0.524577
# 16   0.013395    1.480817       0.514659
# 24   0.012517    1.461085       0.505984
# 114  0.011076    1.457687       0.501524
# 115  0.013719    1.533320       0.622230
# 28   0.013783    1.412030       0.490649
# 108  0.013916    1.352735       0.465077
# 90   0.021056    1.350401       0.483202
# 50   0.026291    1.426693       0.622764
# 32   0.008149    1.294636       0.418855
